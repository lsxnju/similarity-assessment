# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

def load_files_from_folder(folder_path):
    file_list = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if '.mp4' not in file:
              continue
            file_path = os.path.join(root, file)
            file_list.append(file_path)
    return file_list

folder_path = '/content/drive/MyDrive/23-similarity/data'
destination_path = '/content/drive/MyDrive/23-similarity/npy'
files = load_files_from_folder(folder_path)

# %%
import cv2
import numpy as np
import os
for i in range(len(files)):
  cap = cv2.VideoCapture(files[i])
  save_path=os.path.join(destination_path, files[i].split('/')[-1][:-4]+'.npy')
  frameCount = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
  frameWidth = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
  frameHeight = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

  buf = np.empty((frameCount, frameHeight, frameWidth, 3), np.dtype('uint8'))

  fc = 0
  ret = True

  while (fc < frameCount  and ret):
      ret, buf[fc] = cap.read()
      fc += 1

  cap.release()
  np.save(save_path, buf)
  print(save_path)
# Out:
# /content/drive/MyDrive/23-similarity/npy/Mystical1.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical3.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical2.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical4.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical5.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical6.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical7.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical8.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical9.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical10.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical11.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical12.npy
# /content/drive/MyDrive/23-similarity/npy/Mystical13.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-f479efcfecdb> in <cell line: 4>()
#      19
#      20   cap.release()
# ...

# %%
buf.shape
# Out:
# (458, 720, 1280, 3)
